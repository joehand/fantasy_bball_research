# %%
# %matplotlib inline
import matplotlib.pyplot as plt
 
import pandas as pd
from pandas import DataFrame

import seaborn as sns
import statsmodels

import numpy as np

# %%
players = pd.read_csv('../Data/player_zscore.csv')
players
# Out:
#                       PLAYER TEAM POS  MIN_2014  PTS_2014  REB_2014  AST_2014  \
# 0               Kevin Durant  OKC  SF      38.5      32.0       7.4       5.5
# 1              Stephen Curry   GS  PG      36.5      24.0       4.3       8.5
# 2               LeBron James  Cle  SF      37.7      27.1       6.9       6.4
# 3                 Chris Paul  LAC  PG      35.0      19.1       4.3      10.7
# 4               James Harden  Hou  SG      38.0      25.4       4.7       6.1
# 5              Anthony Davis  Nor  PF      35.2      20.8      10.0       1.6
# 6          Russell Westbrook  OKC  PG      30.7      21.8       5.7       6.9
# 7    Michael Carter-Williams  Phi  PG      34.5      16.7       6.2       6.3
# 8                  John Wall  Wsh  PG      36.3      19.3       4.1       8.8
# 9           DeMarcus Cousins  Sac   C      32.4      22.7      11.7       2.9
# 10           Carmelo Anthony   NY  SF      38.7      27.4       8.1       3.1
# ...

# %%
players.hist('AVG_Total_Zscore', bins=12)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x117c65cf8>]], dtype=object)

# %%
x = players['AVG_Total_Zscore']
y = players['RANK']
s = sns.distplot(x, rug=True, hist=False, norm_hist=True)

# %%
x = players['AVG_Total_Zscore']
y = players['RANK']
s = sns.kdeplot(x, cumulative=True)

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 93 columns):
# PLAYER               150 non-null object
# TEAM                 150 non-null object
# POS                  150 non-null object
# MIN_2014             143 non-null float64
# PTS_2014             143 non-null float64
# REB_2014             143 non-null float64
# AST_2014             143 non-null float64
# STL_2014             143 non-null float64
# BLK_2014             143 non-null float64
# 3PM_2014             143 non-null float64
# PTS_ESPN             149 non-null float64
# REB_ESPN             149 non-null float64
# AST_ESPN             149 non-null float64
# STL_ESPN             149 non-null float64
# BLK_ESPN             149 non-null float64
# 3PM_ESPN             149 non-null float64
# MIN_ESPN             149 non-null float64
# MIN_RW               148 non-null float64
# PTS_RW               148 non-null float64
# 3PM_RW               148 non-null float64
# ...

# %%
x = players['BLK_AVG_Zscore']
y = players['REB_AVG_Zscore']
s = sns.kdeplot(x, data2=y)

# %%
s

# %%
one = [{'name':'joe', 'rank':1},{'name':'frank', 'rank':4},{'name':'jeff', 'rank':5}]
two = [{'name':'annie', 'rank':2},{'name':'claire', 'rank':3},{'name':'nava', 'rank':6}]

sorted(np.append(one, two), key=lambda x: x['rank'])
# Out:
# [{'name': 'joe', 'rank': 1},
#  {'name': 'annie', 'rank': 2},
#  {'name': 'claire', 'rank': 3},
#  {'name': 'frank', 'rank': 4},
#  {'name': 'jeff', 'rank': 5},
#  {'name': 'nava', 'rank': 6}]

# %%
np.arrange()
